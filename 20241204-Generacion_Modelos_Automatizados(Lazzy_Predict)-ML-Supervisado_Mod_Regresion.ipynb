# %% [markdown]
# ## Lazy Predict aprendizaje automático
#
# - Ejecutar modelos de aprendizaje automático uno por uno puede ser una tarea compleja.
#
# - Saber cual o cuales modelos son los que mejor se ajustan a nuestro problema puede ser una decisión compleja.
#
# - Hasta el momento hemos revisado algunos modelos, pero no son todos lo que existen en realidad.
#
# - La biblioteca **Lazzy Predict** nos ofrece ejecutar distintos modelos usando unas pocas líneas de código.
#
# - Es fácil de usar y fácil de instalar. Lazy Predict es de código abierto y se publica bajo la licencia MIT.

# %%
#Intalación
# !pip install lazypredict 0.2.13

# %%
#@title Importando las bibliotecas
from lazypredict.Supervised import LazyRegressor
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
#@title Importar datos
df = pd.read_csv('precios_autos_usados_mod.csv', sep = '|')

# %%
df.shape
# Out:
# (7253, 15)

# %%
#@title Primeros Registros
df.head()
# Out:
#    AÑO_FABRICACION  KILOMETROS  RENDIMIENTO   MOTOR  POTENCIA  ASIENTOS  \
# 0             2010       72000        26.60  998.00     58.16         5
# 1             2015       41000        19.67 1582.00    126.20         5
# 2             2011       46000        18.20 1199.00     88.70         5
# 3             2012       87000        20.77 1248.00     88.76         7
# 4             2013       40670        15.20 1968.00    140.80         5
#
#    PRECIO_VENTA  TIPO_COMBUSTIBLE_ELECTRICO  TIPO_COMBUSTIBLE_GLP  \
# 0       1750.00                           0                     0
# 1      12500.00                           0                     0
# 2       4500.00                           0                     0
# 3       6000.00                           0                     0
# 4      17740.00                           0                     0
#
#    TIPO_COMBUSTIBLE_GNC  TIPO_COMBUSTIBLE_PETROLEO  TRANSMISIÓN_MANUAL  \
# ...

# %%
#@title Seleccionar columnas relevantes
y = df['PRECIO_VENTA']

# %%
X = df.drop(columns = 'PRECIO_VENTA')

# %%
# Segmentación de datos
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2023)

# %%
#Entrenado los modelos de regresión
models, predictions = LazyRegressor().fit(X_train, X_test, y_train, y_test)
# Out:
#  98%|█████████▊| 41/42 [00:40<00:00,  1.19it/s]
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001621 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 921
# [LightGBM] [Info] Number of data points in the train set: 5802, number of used features: 12
# [LightGBM] [Info] Start training from score 9387.432609
# 100%|██████████| 42/42 [00:41<00:00,  1.02it/s]

# %% [markdown]
# ## Aplicación LazyRegressor
#
# - Esta biblioteca nos ofrece 41 modelos distintos de parendizaje supervisado para regresión.
#
# - La aplicación de la función nos entrega 2 resultados de salida:
#
#   - models: Se muestran los resultados para los datos de entrenamiento
#
#   - predictions: Se muestran los resultados para los datos de test.
#
# - Dentro de las métricas que podemos obtener están el $R^2$ y RMSE por defecto.
#
# - Por medio del atributo *custom_metric*. podemos elegir la métrica.

# %%
models
# Out:
#                                Adjusted R-Squared  R-Squared      RMSE  \
# Model
# LGBMRegressor                                0.92       0.92   2988.85
# HistGradientBoostingRegressor                0.91       0.91   3149.26
# ExtraTreesRegressor                          0.90       0.90   3205.48
# RandomForestRegressor                        0.90       0.90   3258.81
# XGBRegressor                                 0.90       0.90   3294.45
# GradientBoostingRegressor                    0.90       0.90   3330.31
# BaggingRegressor                             0.89       0.89   3383.26
# KNeighborsRegressor                          0.86       0.87   3787.66
# ExtraTreeRegressor                           0.84       0.84   4130.92
# PoissonRegressor                             0.78       0.79   4789.07
# DecisionTreeRegressor                        0.76       0.76   5008.42
# RidgeCV                                      0.70       0.71   5606.27
# ...

# %%
predictions[:10]
# Out:
#                                Adjusted R-Squared  R-Squared    RMSE  \
# Model
# LGBMRegressor                                0.92       0.92 2988.85
# HistGradientBoostingRegressor                0.91       0.91 3149.26
# ExtraTreesRegressor                          0.90       0.90 3205.48
# RandomForestRegressor                        0.90       0.90 3258.81
# XGBRegressor                                 0.90       0.90 3294.45
# GradientBoostingRegressor                    0.90       0.90 3330.31
# BaggingRegressor                             0.89       0.89 3383.26
# KNeighborsRegressor                          0.86       0.87 3787.66
# ExtraTreeRegressor                           0.84       0.84 4130.92
# PoissonRegressor                             0.78       0.79 4789.07
#
#                                Time Taken
# Model
# LGBMRegressor                        0.32
# HistGradientBoostingRegressor        0.37
# ExtraTreesRegressor                  1.62
# ...

# %%
len(models)
# Out:
# 42

# %% [markdown]
# ## Graficar métricas
#
# Finalmente, graficaremos la metrica seleccionada usando la biblioteca de seaborn

# %%
# Visualizando el mejor modelo
fig, axes = plt.subplots(1, 2, figsize=(15, 10))  # 1 fila, 2 columnas

for i, metrica in enumerate(["R-Squared", "RMSE"]):
    predictions["RMSE"] = [0 if i < 0 else i for i in predictions.iloc[:, 0]]
    sns.set_theme(style="whitegrid")
    ax = sns.barplot(y=predictions.index, x=metrica, data=predictions, ax=axes[i])
    ax.set(xlim=(0, 1))
    ax.set_title(metrica)

plt.tight_layout()  # Ajusta automáticamente la disposición de los subgráficos para evitar superposiciones
plt.show()
